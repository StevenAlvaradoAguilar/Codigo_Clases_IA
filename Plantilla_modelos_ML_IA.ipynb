# %% [markdown]
# <a href="https://colab.research.google.com/github/StevenAlvaradoAguilar/Codigo_Clases_IA/blob/main/Plantilla_modelos_ML_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Análisis del Problema

# %% [markdown]
# # Regresion
#
# ### Autores
#    * Efrén Jiménez

# %% [markdown]
# ## Entendimiento de los Datos

# %% [markdown]
# ## Exploración de los Datos

# %% [markdown]
# ## Modelo de Machine Learning

# %% [markdown]
# ## Evaluación

# %% [markdown]
# ## Resultados
